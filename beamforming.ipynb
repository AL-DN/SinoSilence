# %%
# Author: Alden Sahi
# Project Name: 2D - 2 Element Beaforming
# Project Description: 
    # Input: Audio Stream from Two Directional Microphones
    # Output: A chart that shows the summation of the waves 
            # with different phase shifts applied to sound recieved at the first mic

# %%
import pyaudio

# %%
# lists all audio devices

p = pyaudio.PyAudio()
print("Available audio devices:\n")
for i in range(p.get_device_count()):
    info = p.get_device_info_by_index(i)
    print(f"Index {i}: {info['name']}")
    print(f"  Max Input Channels: {info['maxInputChannels']}")
    print(f"  Max Output Channels: {info['maxOutputChannels']}")
    print(f"  Default Sample Rate: {info['defaultSampleRate']}\n")

p.terminate()
# Out:
# Available audio devices:
#
# Index 0: Microsoft Sound Mapper - Input
#   Max Input Channels: 2
#   Max Output Channels: 0
#   Default Sample Rate: 44100.0
#
# Index 1: Microphone Array (Realtek(R) Au
#   Max Input Channels: 2
#   Max Output Channels: 0
#   Default Sample Rate: 44100.0
#
# Index 2: Stereo Mix (Realtek(R) Audio)
#   Max Input Channels: 2
#   Max Output Channels: 0
#   Default Sample Rate: 44100.0
#
# Index 3: Microsoft Sound Mapper - Output
#   Max Input Channels: 0
#   Max Output Channels: 2
#   Default Sample Rate: 44100.0
#
# Index 4: Speaker (Realtek(R) Audio)
#   Max Input Channels: 0
#   Max Output Channels: 2
#   Default Sample Rate: 44100.0
#
# Index 5: Primary Sound Capture Driver
#   Max Input Channels: 2
#   Max Output Channels: 0
#   Default Sample Rate: 44100.0
#
# Index 6: Microphone Array (Realtek(R) Audio)
#   Max Input Channels: 2
#   Max Output Channels: 0
#   Default Sample Rate: 44100.0
#
# Index 7: Stereo Mix (Realtek(R) Audio)
#   Max Input Channels: 2
#   Max Output Channels: 0
#   Default Sample Rate: 44100.0
#
# Index 8: Primary Sound Driver
#   Max Input Channels: 0
#   Max Output Channels: 2
#   Default Sample Rate: 44100.0
#
# Index 9: Speaker (Realtek(R) Audio)
#   Max Input Channels: 0
#   Max Output Channels: 2
#   Default Sample Rate: 44100.0
#
# Index 10: Speaker (Realtek(R) Audio)
#   Max Input Channels: 0
#   Max Output Channels: 2
#   Default Sample Rate: 48000.0
#
# Index 11: Microphone Array (Realtek(R) Audio)
#   Max Input Channels: 2
#   Max Output Channels: 0
#   Default Sample Rate: 48000.0
#
# Index 12: Stereo Mix (Realtek(R) Audio)
#   Max Input Channels: 2
#   Max Output Channels: 0
#   Default Sample Rate: 48000.0
#
# Index 13: Stereo Mix (Realtek HD Audio Stereo input)
#   Max Input Channels: 2
#   Max Output Channels: 0
#   Default Sample Rate: 48000.0
#
# Index 14: Headphones (Realtek HD Audio 2nd output)
#   Max Input Channels: 0
#   Max Output Channels: 2
#   Default Sample Rate: 44100.0
#
# Index 15: Speakers 1 (Realtek HD Audio output with HAP)
#   Max Input Channels: 0
#   Max Output Channels: 2
#   Default Sample Rate: 48000.0
#
# Index 16: Speakers 2 (Realtek HD Audio output with HAP)
#   Max Input Channels: 0
#   Max Output Channels: 2
#   Default Sample Rate: 44100.0
#
# Index 17: PC Speaker (Realtek HD Audio output with HAP)
#   Max Input Channels: 2
#   Max Output Channels: 0
#   Default Sample Rate: 44100.0
#
# Index 18: Mic in at front panel (black) (Mic in at front panel (black))
#   Max Input Channels: 2
#   Max Output Channels: 0
#   Default Sample Rate: 44100.0
#
# Index 19: Microphone (Realtek HD Audio Mic input)
#   Max Input Channels: 2
#   Max Output Channels: 0
#   Default Sample Rate: 44100.0
